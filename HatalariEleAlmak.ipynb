# %%
def toplama(numara1, numara2):
    return numara1+ numara2

# %%
x = int(input("ilk numarayı giriniz:"))
y = int(input("ikinci numarayı giriniz:"))
toplama (x,y)
# Out:
# ilk numarayı giriniz: 10
# ikinci numarayı giriniz: 20
# 30

# %% [markdown]
# ## try & except & else & finally

# %%
while True:
    try:
        benimInt = int(input("numarayı giriniz:"))
    except:
        print("Lütfen gerçekten numarayı giriniz:")
        continue
    else:
        print("Teşekkürler")
        break
    finally:
        print("finally çağırıldı")
# Out:
# numarayı giriniz: 20
# Teşekkürler
# finally çağırıldı
